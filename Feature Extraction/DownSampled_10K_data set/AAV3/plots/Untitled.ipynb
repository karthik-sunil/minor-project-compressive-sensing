# %%
from PIL import Image,ImageOps
img = Image.open('down_n2.png')
size = (150,150)
fit_and_resized_image = ImageOps.fit(img, size, Image.ANTIALIAS)

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
img = Image.open('/home/karthiksunil/Desktop/7th Sem/Minor Project/data/minor-project-compressive-sensing/Feature Extraction/DownSampled_10K_data set/AAV3/plots/down_n1.png')
size = (150,150)
fit_and_resized_image = ImageOps.fit(img, size, Image.ANTIALIAS)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=360x234 at 0x7FE9686265E0>

# %%
fit_and_resized_image
# Out:
# <PIL.Image.Image image mode=RGBA size=150x150 at 0x7FE9680460D0>
